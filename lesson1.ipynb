# %%
import requests

# %%
from pprint import pprint

# %%
import json

# %% [markdown]
# # Задание 1

# %% [markdown]
# Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
url = 'https://api.github.com'
user='makson1999sh'

# %%
r = requests.get(f'{url}/users/{user}/repos')

# %%
pprint(r.json())
# Out:
# [{'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/branches{/branch}',
#   'clone_url': 'https://github.com/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science.git',
#   'collaborators_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/contributors',
#   'created_at': '2022-11-06T05:14:10Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/deployments',
#   'description': 'Для домашних заданий Geekbrains по библиотекам Python для '
#                  'Data Science',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/downloads',
#   'events_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/forks',
#   'full_name': 'Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science',
#   'git_commits_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/git/tags{/sha}',
#   'git_url': 'git://github.com/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/hooks',
#   'html_url': 'https://github.com/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science',
#   'id': 562362855,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/merges',
#   'milestones_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Howeworks-of-libraries-Python-of-Data-Science',
#   'node_id': 'R_kgDOIYT55w',
#   'notifications_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/notifications{?since,all,participating}',
#   'open_issues': 3,
#   'open_issues_count': 3,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/93063494?v=4',
#             'events_url': 'https://api.github.com/users/Makson1999sh/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/Makson1999sh/followers',
#             'following_url': 'https://api.github.com/users/Makson1999sh/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/Makson1999sh/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/Makson1999sh',
#             'id': 93063494,
#             'login': 'Makson1999sh',
#             'node_id': 'U_kgDOBYwJRg',
#             'organizations_url': 'https://api.github.com/users/Makson1999sh/orgs',
#             'received_events_url': 'https://api.github.com/users/Makson1999sh/received_events',
#             'repos_url': 'https://api.github.com/users/Makson1999sh/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/Makson1999sh/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/Makson1999sh/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/Makson1999sh'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/pulls{/number}',
#   'pushed_at': '2022-12-14T14:49:37Z',
#   'releases_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/releases{/id}',
#   'size': 48,
#   'ssh_url': 'git@github.com:Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/stargazers',
#   'statuses_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/subscription',
#   'svn_url': 'https://github.com/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science',
#   'tags_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/tags',
#   'teams_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science/git/trees{/sha}',
#   'updated_at': '2022-11-06T05:14:10Z',
#   'url': 'https://api.github.com/repos/Makson1999sh/Howeworks-of-libraries-Python-of-Data-Science',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/Makson1999sh/hw3/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/Makson1999sh/hw3/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/Makson1999sh/hw3/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/Makson1999sh/hw3/branches{/branch}',
#   'clone_url': 'https://github.com/Makson1999sh/hw3.git',
#   'collaborators_url': 'https://api.github.com/repos/Makson1999sh/hw3/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/Makson1999sh/hw3/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/Makson1999sh/hw3/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/Makson1999sh/hw3/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/Makson1999sh/hw3/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/Makson1999sh/hw3/contributors',
#   'created_at': '2021-11-27T07:15:22Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/Makson1999sh/hw3/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/Makson1999sh/hw3/downloads',
#   'events_url': 'https://api.github.com/repos/Makson1999sh/hw3/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/Makson1999sh/hw3/forks',
#   'full_name': 'Makson1999sh/hw3',
#   'git_commits_url': 'https://api.github.com/repos/Makson1999sh/hw3/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Makson1999sh/hw3/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Makson1999sh/hw3/git/tags{/sha}',
#   'git_url': 'git://github.com/Makson1999sh/hw3.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/Makson1999sh/hw3/hooks',
#   'html_url': 'https://github.com/Makson1999sh/hw3',
#   'id': 432394502,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/Makson1999sh/hw3/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/Makson1999sh/hw3/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/Makson1999sh/hw3/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/Makson1999sh/hw3/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/Makson1999sh/hw3/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/Makson1999sh/hw3/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/Makson1999sh/hw3/merges',
#   'milestones_url': 'https://api.github.com/repos/Makson1999sh/hw3/milestones{/number}',
#   'mirror_url': None,
#   'name': 'hw3',
#   'node_id': 'R_kgDOGcXRBg',
#   'notifications_url': 'https://api.github.com/repos/Makson1999sh/hw3/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/93063494?v=4',
#             'events_url': 'https://api.github.com/users/Makson1999sh/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/Makson1999sh/followers',
#             'following_url': 'https://api.github.com/users/Makson1999sh/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/Makson1999sh/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/Makson1999sh',
#             'id': 93063494,
#             'login': 'Makson1999sh',
#             'node_id': 'U_kgDOBYwJRg',
#             'organizations_url': 'https://api.github.com/users/Makson1999sh/orgs',
#             'received_events_url': 'https://api.github.com/users/Makson1999sh/received_events',
#             'repos_url': 'https://api.github.com/users/Makson1999sh/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/Makson1999sh/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/Makson1999sh/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/Makson1999sh'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/Makson1999sh/hw3/pulls{/number}',
#   'pushed_at': '2021-11-27T07:37:35Z',
#   'releases_url': 'https://api.github.com/repos/Makson1999sh/hw3/releases{/id}',
#   'size': 1,
#   'ssh_url': 'git@github.com:Makson1999sh/hw3.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/Makson1999sh/hw3/stargazers',
#   'statuses_url': 'https://api.github.com/repos/Makson1999sh/hw3/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/Makson1999sh/hw3/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Makson1999sh/hw3/subscription',
#   'svn_url': 'https://github.com/Makson1999sh/hw3',
#   'tags_url': 'https://api.github.com/repos/Makson1999sh/hw3/tags',
#   'teams_url': 'https://api.github.com/repos/Makson1999sh/hw3/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/Makson1999sh/hw3/git/trees{/sha}',
#   'updated_at': '2021-11-27T07:37:38Z',
#   'url': 'https://api.github.com/repos/Makson1999sh/hw3',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/Makson1999sh/Python/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/Makson1999sh/Python/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/Makson1999sh/Python/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/Makson1999sh/Python/branches{/branch}',
#   'clone_url': 'https://github.com/Makson1999sh/Python.git',
#   'collaborators_url': 'https://api.github.com/repos/Makson1999sh/Python/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/Makson1999sh/Python/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/Makson1999sh/Python/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/Makson1999sh/Python/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/Makson1999sh/Python/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/Makson1999sh/Python/contributors',
#   'created_at': '2021-10-24T04:04:25Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/Makson1999sh/Python/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/Makson1999sh/Python/downloads',
#   'events_url': 'https://api.github.com/repos/Makson1999sh/Python/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/Makson1999sh/Python/forks',
#   'full_name': 'Makson1999sh/Python',
#   'git_commits_url': 'https://api.github.com/repos/Makson1999sh/Python/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Makson1999sh/Python/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Makson1999sh/Python/git/tags{/sha}',
#   'git_url': 'git://github.com/Makson1999sh/Python.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/Makson1999sh/Python/hooks',
#   'html_url': 'https://github.com/Makson1999sh/Python',
#   'id': 420582811,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/Makson1999sh/Python/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/Makson1999sh/Python/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/Makson1999sh/Python/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/Makson1999sh/Python/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/Makson1999sh/Python/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/Makson1999sh/Python/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/Makson1999sh/Python/merges',
#   'milestones_url': 'https://api.github.com/repos/Makson1999sh/Python/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Python',
#   'node_id': 'R_kgDOGRGVmw',
#   'notifications_url': 'https://api.github.com/repos/Makson1999sh/Python/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/93063494?v=4',
#             'events_url': 'https://api.github.com/users/Makson1999sh/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/Makson1999sh/followers',
#             'following_url': 'https://api.github.com/users/Makson1999sh/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/Makson1999sh/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/Makson1999sh',
#             'id': 93063494,
#             'login': 'Makson1999sh',
#             'node_id': 'U_kgDOBYwJRg',
#             'organizations_url': 'https://api.github.com/users/Makson1999sh/orgs',
#             'received_events_url': 'https://api.github.com/users/Makson1999sh/received_events',
#             'repos_url': 'https://api.github.com/users/Makson1999sh/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/Makson1999sh/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/Makson1999sh/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/Makson1999sh'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/Makson1999sh/Python/pulls{/number}',
#   'pushed_at': '2021-10-24T04:04:26Z',
#   'releases_url': 'https://api.github.com/repos/Makson1999sh/Python/releases{/id}',
#   'size': 0,
#   'ssh_url': 'git@github.com:Makson1999sh/Python.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/Makson1999sh/Python/stargazers',
#   'statuses_url': 'https://api.github.com/repos/Makson1999sh/Python/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/Makson1999sh/Python/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Makson1999sh/Python/subscription',
#   'svn_url': 'https://github.com/Makson1999sh/Python',
#   'tags_url': 'https://api.github.com/repos/Makson1999sh/Python/tags',
#   'teams_url': 'https://api.github.com/repos/Makson1999sh/Python/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/Makson1999sh/Python/git/trees{/sha}',
#   'updated_at': '2021-10-24T04:04:28Z',
#   'url': 'https://api.github.com/repos/Makson1999sh/Python',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/branches{/branch}',
#   'clone_url': 'https://github.com/Makson1999sh/Solar-System.git',
#   'collaborators_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/contributors',
#   'created_at': '2022-10-14T02:11:32Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/downloads',
#   'events_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/forks',
#   'full_name': 'Makson1999sh/Solar-System',
#   'git_commits_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/git/tags{/sha}',
#   'git_url': 'git://github.com/Makson1999sh/Solar-System.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/hooks',
#   'html_url': 'https://github.com/Makson1999sh/Solar-System',
#   'id': 551206340,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/merges',
#   'milestones_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Solar-System',
#   'node_id': 'R_kgDOINq9xA',
#   'notifications_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/93063494?v=4',
#             'events_url': 'https://api.github.com/users/Makson1999sh/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/Makson1999sh/followers',
#             'following_url': 'https://api.github.com/users/Makson1999sh/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/Makson1999sh/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/Makson1999sh',
#             'id': 93063494,
#             'login': 'Makson1999sh',
#             'node_id': 'U_kgDOBYwJRg',
#             'organizations_url': 'https://api.github.com/users/Makson1999sh/orgs',
#             'received_events_url': 'https://api.github.com/users/Makson1999sh/received_events',
#             'repos_url': 'https://api.github.com/users/Makson1999sh/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/Makson1999sh/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/Makson1999sh/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/Makson1999sh'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/pulls{/number}',
#   'pushed_at': '2022-10-14T02:11:33Z',
#   'releases_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/releases{/id}',
#   'size': 0,
#   'ssh_url': 'git@github.com:Makson1999sh/Solar-System.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/stargazers',
#   'statuses_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/subscription',
#   'svn_url': 'https://github.com/Makson1999sh/Solar-System',
#   'tags_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/tags',
#   'teams_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/Makson1999sh/Solar-System/git/trees{/sha}',
#   'updated_at': '2022-10-14T02:11:32Z',
#   'url': 'https://api.github.com/repos/Makson1999sh/Solar-System',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False}]

# %%
with open('data.json', 'w') as f:
    json.dump(r.json(), f)

# %%
for i in r.json():
    print(i['name'])
# Out:
# Howeworks-of-libraries-Python-of-Data-Science
# hw3
# Python
# Solar-System
